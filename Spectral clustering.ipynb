# %%
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Mall_Customers.csv")
#dataset

# %%
X=dataset.iloc[ : ,3:5]
#X

# %%
from sklearn.cluster import SpectralClustering
clustering = SpectralClustering(n_clusters=8,assign_labels='cluster_qr',random_state=40).fit(X)
y_spec=clustering.fit_predict(X)
y_spec
# Out:
# C:\Users\poorn\Anaconda3\envs\aiml\lib\site-packages\sklearn\manifold\_spectral_embedding.py:392: UserWarning: Exited at iteration 2000 with accuracies
# [3.49441892e-14 2.84658534e-07 8.45844637e-07 7.54137515e-07
#  1.00189132e-06 6.24940169e-07 1.21791954e-06 8.43287188e-07
#  8.26739872e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
# Use iteration 1867 instead with accuracy
# 1.0481416053915463e-06.
#
#   _, diffusion_map = lobpcg(
# C:\Users\poorn\Anaconda3\envs\aiml\lib\site-packages\sklearn\manifold\_spectral_embedding.py:392: UserWarning: Exited postprocessing with accuracies
# [5.75946406e-15 2.46765938e-07 7.77106555e-07 6.26159587e-07
#  9.22099610e-07 6.36440661e-07 1.15357238e-06 8.55921415e-07
#  4.21520808e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
#   _, diffusion_map = lobpcg(
# ...

# %%
supervised=pd.DataFrame(dataset)

# %%
supervised['cluster-group']=y_spec
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      cluster-group
# 0                6
# 1                5
# 2                4
# ...

# %%
supervised.to_csv('cluster.csv',index=False)

# %%
#!pip install seaborn

# %%
import seaborn as sns
facet=sns.lmplot(data=supervised,x=supervised.columns[3],y=supervised.columns[4],hue=supervised.columns[5],legend=True,legend_out=True)
# Out:
# C:\Users\poorn\Anaconda3\envs\aiml\lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
